# %%
from manage_data.compute_alpha import compute_alpha
from manage_data.plot_func import *
from manage_data.evaluation import evaluate_alpha

# %%
alpha_PD = compute_alpha(alpha_class='Alpha101', alpha_index=54)
plot_all(alpha_PD)
# Out:
# Report items with different ranks:
# 5.0    1328840
# 2.0    1103415
# 3.0    1103402
# 4.0    1103318
# 1.0    1073369
# Name: factor_rank_bin, dtype: int64
# ========================================================================
# ========================================================================
# The mean of IC is 0.028973896699266713;
# The standardized IC is 0.29359604531512873.

# %%
print("Evaluate the performance:")
evaluate_alpha(alpha_PD)
# Out:
# Evaluate the performance:
#   group_name    return    sharpe       std  winratio       mdd
# 0          1 -0.275191 -0.952847  0.018193  0.474476 -1.449237
# 1          2 -0.189550 -0.626389  0.019063  0.501343 -1.205375
# 2          3 -0.130963 -0.420454  0.019621  0.513702 -1.013382
# 3          4 -0.112333 -0.353658  0.020009  0.527136 -0.958338
# 4          5 -0.005027 -0.015884  0.019937  0.545943 -0.570995
# 5       diff  0.270164  2.197518  0.007745  0.669533 -0.794304
