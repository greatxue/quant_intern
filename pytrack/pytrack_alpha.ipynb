# %%
from manage_data.compute_alpha import compute_alpha
from manage_data.plot_func import *
from manage_data.evaluation import evaluate_alpha

# %%
alpha_PD = compute_alpha(alpha_class='AlphaCal24', alpha_index=2)
plot_all(alpha_PD)
# Out:
# Data volume for different ranks:
# 5.0    1135456
# 2.0    1104537
# 4.0    1104537
# 3.0    1104025
# 1.0    1073086
# Name: factor_rank_bin, dtype: int64
# ...
# The mean of IC is 0.002514905895714984;
# The standardized IC is 0.024420658197530733.

# %%
print("Evaluate the performance:")
evaluate_alpha(alpha_PD)
# Out:
# Evaluate the performance:
#   group_name    return    sharpe       std  winratio       mdd
# 0          1 -0.348033 -1.050513  0.020870  0.500000 -1.927067
# 1          2 -0.287920 -0.901644  0.020116  0.505965 -1.699096
# 2          3 -0.235304 -0.756524  0.019593  0.513015 -1.472892
# 3          4 -0.216501 -0.718036  0.018994  0.509761 -1.374080
# 4          5 -0.197584 -0.677747  0.018365  0.509761 -1.277906
# 5       diff  0.150449  1.505802  0.006294  0.540672 -0.099336
