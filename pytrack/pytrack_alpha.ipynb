# %%
from manage_data.compute_alpha import compute_alpha
from manage_data.plot_func import *
from manage_data.evaluation import evaluate_alpha

# %%
alpha_PD = compute_alpha(alpha_class='AlphaCal24', alpha_index=2)
plot_all(alpha_PD)
# Out:
# Data volume for different ranks:
# 5.0    1138058
# 2.0    1107047
# 4.0    1107047
# 3.0    1106521
# 1.0    1075558
# Name: factor_rank_bin, dtype: int64
# ========================================================================
# ========================================================================
# The mean of IC is 0.0025599581570609465;
# The standardized IC is 0.024875340968226436.

# %%
print("Evaluate the performance:")
evaluate_alpha(alpha_PD)
# Out:
# Evaluate the performance:
#   group_name    return    sharpe       std  winratio       mdd
# 0          1 -0.348083 -1.050874  0.020866  0.500000 -1.927591
# 1          2 -0.288855 -0.904494  0.020117  0.507592 -1.702455
# 2          3 -0.234521 -0.754281  0.019586  0.513015 -1.469595
# 3          4 -0.217240 -0.720412  0.018996  0.508677 -1.378005
# 4          5 -0.197591 -0.677916  0.018361  0.509761 -1.277558
# 5       diff  0.150493  1.509289  0.006281  0.542299 -0.098420
